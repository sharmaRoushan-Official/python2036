# %% [markdown]
# SRING

# %%
str1= "Hello World"
print(str1)
# Out:
# Hello World

# %%
str1="Damini"
print(len(str1))
# Out:
# 6

# %%
str1="damini"
print(str1.upper())
# Out:
# DAMINI

# %%
str1="DAMINI"
print(str1.lower())
# Out:
# damini

# %%
str1="Education"
count=0
for ch in str1.lower():
    if ch in "aeiou":
        count+=1
print(count)
# Out:
# 5

# %%
str1="Damini"
print(str1[::-1])
# Out:
# inimaD

# %%
str="damini"
if str1=str1[::-1]:
    print("Palindrome")
else:
    print("Not Palindrome")
# Out:
#   Cell In[7], line 2
#     if str1=str1[::-1]:
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
str1="damini"
if str1==str1[::-1]:
    print("Palindrome")
else:
    print("Not Palindrome")
# Out:
# Not Palindrome

# %%
str1="mango"
print(str1.count('a'))
# Out:
# 1

# %%
str1="I like swimming "
new_str=str1.replace("swimming","books")
print(new_str)
# Out:
# I like books

# %%
str1="my name is damini"
print(str1.split())
# Out:
# ['my', 'name', 'is', 'damini']
