# %% [markdown]
# List questions

# %%
num=[10,20,30,40,50]
print(num)
# Out:
# [10, 20, 30, 40, 50]

# %%
num=[1,2,3,4,5]
print(len(num))
# Out:
# 5

# %%
num=[1,2,3]
num.append(4)
print(num)
# Out:
# [1, 2, 3, 4]

# %%
num=[1,2,4]
num.insert(2,3)
print(num)
# Out:
# [1, 2, 3, 4]

# %%
num=[10,20,30,40]
num.remove(30)
print(num)
# Out:
# [10, 20, 40]

# %%
num=[12,45,7,89,23]
print(max(num))
# Out:
# 89

# %%
num=[12,45,7,89,23]
print(min(num))
# Out:
# 7

# %%
num=[5,2,8,1]
num.sort()
print(num)
# Out:
# [1, 2, 5, 8]

# %%
num=[1,2,2,3,2,4]
print(num.count(2))
# Out:
# 3

# %%
num=[1,2,3,4]
num.reverse()
print(num)
# Out:
# [4, 3, 2, 1]
