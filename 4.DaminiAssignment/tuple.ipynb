# %%
t=(10,20,30,40,50)
print(t)
# Out:
# (10, 20, 30, 40, 50)

# %%
t=(1,2,3,4)
print(len(t))
# Out:
# 4

# %%
t=(10,20,30,40)
print(t[2])
# Out:
# 30

# %%
t=(10,20,30,40)
if 20 in t:
    print("Element exists")
else:
    print("not fount")
# Out:
# Element exists

# %%
t=(1,2,2,3,2)
print(t.count(2))
# Out:
# 3

# %%
t=(10,20,30,40)
print(t.index(30))
# Out:
# 2

# %%
t1=(1,2)
t2=(3,4)
t3=t1+t2
print(t3)
# Out:
# (1, 2, 3, 4)

# %%
t=(10,20,30)
lst=list(t)
print(lst)
# Out:
# [10, 20, 30]

# %%
t=(5,2,9,1)
print(max(t))
print(min(t))
# Out:
# 9
# 1

# %%
t=(10,20,30)
for i in t:
    print(i)
# Out:
# 10
# 20
# 30
