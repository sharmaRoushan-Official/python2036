# %% [markdown]
# Mixed questions

# %%
str1="Hello"
lst=list(str1)
print(lst)
# Out:
# ['H', 'e', 'l', 'l', 'o']

# %%
names=["damini","karan","shlok"]
t = tuple(names)
print(t)
# Out:
# ('damini', 'karan', 'shlok')

# %%
list1=[1,2,3,4]
list2=[3,4,5,6]
common=[]
for i in list1:
    if i in list2:
        common.append(i)
print(common)
# Out:
# [3, 4]

# %%
t=('P','y','t','h','o','n')
str1=''.join(t)
print(str1)
# Out:
# Python

# %%
9
