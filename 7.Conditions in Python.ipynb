# %% [markdown]
# ## 7. Conditions in Python
#
# ----
#
# 1. What is a conditional Statement
#
# A `Conditional statement` allows a program to make decidions based on conditions(True/False).
#
# ### Interpreter(python)
# * if
# * elif
# * else
#
# ### Compiler (c)
# * if
# * elif-if
# * else

# %% [markdown]
# ### 2. Syntax of if-statement
#
# ✅ syntax:
#
# if condition:
#
#     # code executes if condition becomes True.

# %%
age = 19

if age>=18:
    print("You are elegible to vote")
# Out:
# You are elegible to vote

# %% [markdown]
# KeyPoints:
#
# * Condition must return True/False
# * Indentation is Mandatory/Block True/False
# * No parentheses is required(unlike C/Java)

# %% [raw]
# ### 3. if-else Statement
#
# syntax:
#
# if condition:
#     ### True Block
# else:
#     ### False Block
#
# ### If Condition returns False then Else will be executed.

# %%
age = 16

if age>=18:
    print("Adult")
else:
    print("Minor")
# Out:
# Minor

# %% [markdown]
# keypoint:
#
# * else runs when condition is False
# * Only one else allowed per if
# * else is optional

# %%
x = int(input("Enter any number: "))
print(x,type(x))

### Notes: If you using input() then withoutdata it declare string type
# Out:
# Enter any number:  15
# 15 <class 'int'>

# %% [markdown]
# ### 4.if-elif-else  Ladder if
#
# ---

# %% [raw]
# syntax:
#
# if condition1:
#     statement1
# elif condition2:
#     statement2
# elif condition3:
#     statement3
# elif condition4:
#     statement4
# else:
#     statement5

# %%
marks = int(input("Enter your marks: "))

### 90-100 "A", 80-90 "B", 70-80: "C", 60-70 -"D", 50-60-"E" 40-50 -"Fail"

if marks>=90 and marks<=100:
    print("Grade:A")
elif marks>=80 and marks<90:
    print("Grade:B")
elif marks>=70 and marks<80:
    print("Grade:C")
elif marks>=60 and marks<70:
    print("Grade:D")
elif marks>=50 and marks<60:
    print("Grade:E")
else:
    print("Fail")
# Out:
# Enter your marks:  101
# Fail

# %% [markdown]
# ### 5.Nested if Statements
#
# Example:

# %%
age = 21
citizen = True

if age>=18:   # not output
    if citizen:
        print("Elegible to Vote")
    else:
        print("Not Elegible to vote")
else:
    print("Underage")
# Out:
# Elegible to Vote

# %%
age>=18
# Out:
# True

# %% [markdown]
# Keypoint:
#
# * if inside another if---Nested contioins
# * Useful for multi-level conditions.

# %% [markdown]
# ### 6.Short-hand (One line)

# %%
age = 17

if age>=18:print("Adult")

# %% [markdown]
# ### 7. Ternary Operator(Inlide if-else)
#
#
# syntax:
#
# value_if_true  if condition else value_if_false

# %%
age = 15

"Adult" if age>=18 else "Minor"
# Out:
# 'Minor'

# %% [markdown]
# ### 8. Truthy and Falsy Values
#
# ** Falsy values:
#
# * False
# * None
# * 0
# * "" (empty string)
# * '' (empty string)
# * [],(),{}

# %%
name = False

if name:
    print('Name Exits')
else:
    print("Empty Name")
# Out:
# Empty Name

# %%
name = None

if name:
    print('Name Exits')
else:
    print("Empty Name")
# Out:
# Empty Name

# %%
name = 0

if name:
    print('Name Exits')
else:
    print("Empty Name")
# Out:
# Empty Name

# %%
name = ""

if name:
    print('Name Exits')
else:
    print("Empty Name")
# Out:
# Empty Name

# %%
name = ''

if name:
    print('Name Exits')
else:
    print("Empty Name")
# Out:
# Empty Name

# %%
name = ""

if name:
    print('Name Exits')
else:
    print("Empty Name")
# Out:
# Empty Name

# %%
name = ()

if name:
    print('Name Exits')
else:
    print("Empty Name")
# Out:
# Empty Name

# %%
name = {}

if name:
    print('Name Exits')
else:
    print("Empty Name")
# Out:
# Empty Name

# %%
### 9. Using pass in Coditions

if True:
    pass # paceholder
    print("hello")
# Out:
# hello

# %%
ord( )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 ord( )
#
# TypeError: ord() takes exactly one argument (0 given)

# %% [markdown]
# ### 10. Using in or not-in
# ### Membership operator - [in, not-in]

# %%
fruits = ["apple","banana","mango","strawberry","grapes"]

if 'apple' in fruits:
    print("Available")
else:
    print("Not Available")
# Out:
# Available

# %%
fruits = ["apple","banana","mango","strawberry","grapes"]

fruitsName = input("Enter any fruits: ")
if fruitsName in fruits:
    print("Available")
else:
    print("Not Available")
# Out:
# Enter any fruits:  grapes
# Available

# %% [markdown]
# ## 11. Multiple Conditions in One Line [And, or, not]

# %%
x = 3

if x>5 and x<15:
    print(x,"is Between 5 and 15")
else:
    print(x,"is not between 5 and 15")
# Out:
# 3 is not between 5 and 15

# %% [markdown]
# ### 14. Chained Comparison

# %%
x = 3

if 5< x <15:
    print("Valid range")

# %% [markdown]
# ### 15. Case statement

# %%
day = 4

match day:
    case 1:
        print("Monday")
    case 2:
        print("Tuesday")
    case 3:
        print("Wednesday")
    case 4:
        print("Thursday")
    case 5:
        print("Friday")
    case 6:
        print('Saturday')
    case 7:
        print("Sunday")
    case 8:
        print('invalid weekday')
# Out:
# Thursday

# %%
## 8. leap year

# %%
### 18. check wheter the enter password is stored password

password = "admin"

password1= input("Enter your password: ")


if password1 == password:
    print("Access Granted")
else:
    print("Access Denied")
# Out:
# Enter your password:  admin
# Access Granted

# %%
### 25. Write the python program to calculate the electricity bill 

<= 100 units ---> 1 per unit
101-200 units ---> 1.5 per unit
>200 units -----> 2 per unit

# %%
### 21. write a program to calculate discount based on purchased amount

# > 1000 ---- 20 percent
# >500 <1000 ---> 10 %
# <5000 ----> No discount


price = float(input("Enter shopping price: "))

if price>=1000:
    dis = "20%"
    discount = (price*20)/100
    # print(discount)
    discountAmount = price - discount
    # print(discountAmount)
    print(f"Total Shopping Amount: {price}\nTotal discount get: {dis}\nTotal Discount Amount:{discount}\nTotal Amount to pay:{discountAmount}")
elif price>=500 and price<1000:
    dis = "10%"
    discount = (price*10)/100
    # print(discount)
    discountAmount = price - discount
    # print(discountAmount)
    print(f"Total Shopping Amount: {price}\nTotal discount get: {dis}\nTotal Discount Amount:{discount}\nTotal Amount to pay:{discountAmount}")
    getDiscount = 1000-price
    print(f"Note:\nShop More amount₹ {getDiscount} and get 20% Discount")
else:
    dis = "0%"
    discount = (price*0)/100
    # print(discount)
    discountAmount = price - discount
    # print(discountAmount)
    print(f"Total Shopping Amount: {price}\nTotal discount get: {dis}\nTotal Discount Amount:{discount}\nTotal Amount to pay:{discountAmount}")

    getDiscount = 500-price
    print(f"Note:\nShop More amount₹ {getDiscount} and get 10% Discount")
# Out:
# Enter shopping price:  550
# Total Shopping Amount: 550.0
# Total discount get: 10%
# Total Discount Amount:55.0
# Total Amount to pay:495.0
# Note:
# Shop More amount₹ 450.0 and get 20% Discount

# %%
units = int(input("Enter electricity units: "))

if units <= 100:
    bill = units * 1

elif units <= 200:
    bill = units * 1.5

else:
    bill = units * 2

print("Electricity Bill =", bill)

# %% [markdown]
# ![image.png](attachment:5a5b1c5e-b780-43d2-990a-f3d1ec49bbf4.png)

# %% [markdown]
# ![image.png](attachment:14141a2c-fb30-4df1-8114-ecbed108cb7c.png)

# %%
wh = int(input("Enter your consumed whatt hours: "))
