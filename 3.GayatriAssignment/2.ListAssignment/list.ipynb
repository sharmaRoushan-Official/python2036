# %% [markdown]
# ```Q. create a list of 5 numbers and print it```

# %%
numbers = [10,20,30,40,50]
print("The list is:", numbers)
# Out:
# The list is: [10, 20, 30, 40, 50]

# %% [markdown]
# ```Q. write a program to find the lenght of the string```

# %%
l = "Hello"
print(len(l))
# Out:
# 5

# %% [markdown]
# ```Q. write a program to add an element to the end an element to the end of the list```

# %%
numbers = [10, 20, 30]
numbers.append(40)
print(numbers)
# Out:
# [10, 20, 30, 40]

# %% [markdown]
# ```Q. write a program to insert an element at a specific position in a list```

# %%
numbers = [100,200,300,500]
numbers.insert(3,400)
print(numbers)
# Out:
# [100, 200, 300, 400, 500]

# %% [markdown]
# ```Q. write a program to remove an element from the list```

# %%
numbers = [1,2,3,4,5,6,7,8]
numbers.remove(3)
numbers.remove(7)
print(numbers)
# Out:
# [1, 2, 4, 5, 6, 8]

# %% [markdown]
# ```Q. write a program to find the largest number in a list```

# %%
numbers =(307,678,980,546)
print(max(numbers))
# Out:
# 980

# %% [markdown]
# ```Q. write a program to find the smallest number in a list```

# %%
numbers = (7890,2345,7689,4356)
print (min(numbers))
# Out:
# 2345

# %% [markdown]
# ```Q. write a program to sort a list in ascending order.```

# %%
numbers = [89,457,87,84,35,754,975,124,43,16,87,40,86]
print(numbers)
numbers.sort()
print (numbers)
# Out:
# [89, 457, 87, 84, 35, 754, 975, 124, 43, 16, 87, 40, 86]
# [16, 35, 40, 43, 84, 86, 87, 87, 89, 124, 457, 754, 975]

# %% [markdown]
# ```Q. write a program to count how many times a specific element appears in a list```

# %%
numbers = [4,2,41,4,4,4,7,67,67,87,87,87,1,23]
print(numbers)
print (numbers.count(4))
print (numbers.count(7))
print (numbers.count(1))
print (numbers.count(67))
print (numbers.count(87))
# Out:
# [4, 2, 41, 4, 4, 4, 7, 67, 67, 87, 87, 87, 1, 23]
# 4
# 1
# 1
# 2
# 3

# %% [markdown]
# ```Q. write a code to reverse a list```

# %%
numbers = [90,56,98,1,4,3,87,0,56,13,77,90,38,94,69,19,66,69,88,9,3]
print(numbers)
numbers.reverse()
print(numbers)
# Out:
# [90, 56, 98, 1, 4, 3, 87, 0, 56, 13, 77, 90, 38, 94, 69, 19, 66, 69, 88, 9, 3]
# [3, 9, 88, 69, 66, 19, 69, 94, 38, 90, 77, 13, 56, 0, 87, 3, 4, 1, 98, 56, 90]
