# %%
a = input("Enter a string: ")
print(a)
# Out:
# Enter a string:  hello
# hello

# %%
a = input("Enter a string: ")
print(len(a))
# Out:
# Enter a string:  hello
# 6

# %%
a = input("Enter a string: ")
print(a.upper())
# Out:
# Enter a string:  hello
# HELLO

# %%
a = input ("Enter a string:")
print(a.lower())
# Out:
# Enter a string: HELLOOOOOOOOOOOO
# helloooooooooooo

# %%
a = input("Enter a string: ")
print(a[::-1])
# Out:
# Enter a string:  HELLLO
# OLLLEH

# %%
a = input("Enter a string: ")
b = input("Enter a word to insert: ")
print(a + " " + b)
# Out:
# Enter a string:  HELLO
# Enter a word to insert:  HIIII
# HELLO HIIII

# %%
a = input("Enter a string: ")
ch = input("Enter a character: ")
print(a.count(ch))
# Out:
# Enter a string:  WELCOME TO PYTHON CODING
# Enter a character:  ABCD
# 0

# %%
a = input("Enter a string: ")
old = input("Enter the word to replace: ")
new = input("Enter the new word: ")
print(a.replace(old, new))
# Out:
# Enter a string:  PYTHON
# Enter the word to replace:  C++
# Enter the new word:  C++
# PYTHON

# %%
a = input("Enter a sentence: ")
print(a.split())
# Out:
# Enter a sentence:  PYTHON
# ['PYTHON']
