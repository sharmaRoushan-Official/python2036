# %% [markdown]
# ```Q. Create a tuple containing 5 different values and print it.```

# %%
DATA = ("JAPAN", "TOKYO",101)
print(DATA)
DATA = ("BRAZIL","BRASILIA", 102)
print(DATA)
DATA = ("ITALY","ROME",103)
print(DATA)
# Out:
# ('JAPAN', 'TOKYO', 101)
# ('BRAZIL', 'BRASILIA', 102)
# ('ITALY', 'ROME', 103)

# %% [markdown]
# ```Q. Write a program to find the length of a tuple.```

# %%
numbers = (6789,980,54688,23566,897876,677,98,856)
print(len(numbers))
# Out:
# 8

# %% [markdown]
# ```Q.Write a program to access the third element of a tuple```

# %%
numbers = (10, 20, 30, 40, 50)
print(numbers[2])
# Out:
# 30

# %% [markdown]
# ```Q. Write a program to check whether an element exists in a tuple```

# %%
color  = ("red" ,"black","yellow")
print(color)
print("red" in color)
print ("RED" in color )
# Out:
# ('red', 'black', 'yellow')
# True
# False

# %% [markdown]
# ```Q. Write a program to count the occurrence of a specific value in a tuple ```

# %%
numbers = (200,400)
print(numbers.count(200))
print(numbers.count(400))
# Out:
# 1
# 1

# %% [markdown]
# ```Q. Write a program to find the index of a given element in a tuple```

# %%
numbers = (678,987,567,765)
numbers.index(678)
# Out:
# 0

# %% [markdown]
# ```Q. Write a program to concatenate two tuples```

# %%
tuple1 = (1, 2, 3)
tuple2 = (4, 5, 6)
tuple = tuple1 + tuple2
print(tuple)
# Out:
# (1, 2, 3, 4, 5, 6)

# %% [markdown]
# ```Q. Write a program to convert a tuple into a lis```

# %%
numbers=(100,102,103,104,105)
print(numbers)
temp= list(numbers)
temp[0]=101
print(temp)
# Out:
# (100, 102, 103, 104, 105)
# [101, 102, 103, 104, 105]

# %% [markdown]
# ```Q. Write a program to find the maximum and minimum values in a tuple```

# %%
numbers = (879,990,768,654,908,234)
print(numbers)
print (min (numbers))
print (max ( numbers))
# Out:
# (879, 990, 768, 654, 908, 234)
# 234
# 990

# %% [markdown]
# Q. 10. Write a program to iterate through all elements of a tuple and print them.

# %% [markdown]
# Q. Accept a string from the user and store each character in a list.

# %%
s = input("Enter a string: ")
char = list(s)
print(char)
# Out:
# Enter a string:  hello
# ['h', 'e', 'l', 'l', 'o']

# %% [markdown]
# Q. Convert a list of names into a tuple.

# %%
names = ["ABC", "XYZ", "PQR"]
print(tuple(names))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[89], line 3
#       1 names = ["ABC", "XYZ", "PQR"]
# ----> 3 print(tuple(names))
#
# TypeError: 'list' object is not callable

# %%
names = ["ABC", "XYZ", "PQR"]
temp = tuple(names)
print(temp)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[90], line 2
#       1 names = ["ABC", "XYZ", "PQR"]
# ----> 2 temp = tuple(names)
#       3 print(temp)
#
# TypeError: 'list' object is not callable

# %% [markdown]
# Q. Find common elements between two lists

# %%
list1 = [1, 2, 3, 4, 5]
list2 = [3, 4, 5, 6, 7]
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>
