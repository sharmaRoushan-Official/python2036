# %% [markdown]
# ### List Questions

# %% [markdown]
# 1)Create a list of 5 numbers and print it

# %%
list = [1,2,3,4,5]
print(list,type(list))
# Out:
# [1, 2, 3, 4, 5] <class 'list'>

# %% [markdown]
# ------------------------------
# 2) Write a program to find the length of a list.

# %%
list = [1,2,3,4,5]
print(len(list))
# Out:
# 5

# %% [markdown]
# ----------------------------
# 3)Write a program to add an element to the end of a list.

# %%
list = [1, 23.3, "Nikhil", None, True]
print(list.append(False))
print(list)
# Out:
# None
# [1, 23.3, 'Nikhil', None, True, False]

# %% [markdown]
# --------------
# 4)Write a program to insert an element at a specific position in a list.

# %%
list = [1, 23.3, "Nikhil", None, True]
l1 = list.insert(2, "Apple")
print(list)
# Out:
# [1, 23.3, 'Apple', 'Nikhil', None, True]

# %% [markdown]
# -----------------
# 5)Write a program to remove an element from a list.

# %%
list = [1, 23.3, 'Apple', 'Nikhil', None, True]
l1 = list.remove("Apple")
print(list)
# Out:
# [1, 23.3, 'Nikhil', None, True]

# %% [markdown]
# ----------------
# 6) Write a program to find the largest number in a list.

# %%
list = [1,2,3,4,7,8,10]
l1 = max(list) 
print(l1)
# Out:
# 10

# %% [markdown]
# ------------------------
# 7) Write a program to find the smallest number in a list.

# %%
list = [1,2,3,4,7,8,10]
l1 = min(list)
print(l1)
# Out:
# 1

# %% [markdown]
# ----------------
# 8)Write a program to sort a list in ascending order.

# %%
list = [3,25,6,178,5,10]
l1 = list.sort()
print(l1)
print(list)
# Out:
# None
# [3, 5, 6, 10, 25, 178]

# %% [markdown]
# ---------------------------
# 9)Write a program to count how many times a specific element appears in a list.

# %%
list = [1,2,3,2,4,2,10]
print(list.count(2))
# Out:
# 3

# %% [markdown]
# ------------------
# 10)Write a program to reverse a list.

# %%
list = [3,25,6,178,5,10]
list.reverse()
print(list)
# Out:
# [10, 5, 178, 6, 25, 3]
