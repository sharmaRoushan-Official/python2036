# %% [markdown]
# ### 19. JSON in Python
#
# #### What is JSON?
#
# JSON = JavaScript Object Notation
#
# It is a lightweigh data format used to store and exchange data.
#
# 📌 Used in:
# * Web APIs
# * Dajngo/Flask
# * Frontend ⮂ Backend communication
# * Config Files
#
#
# ----
# JSON vs Python Dictionary
#
# JSON Looks like a Python dictioanry but there are differences
#
# |Feature|JSON|Python Dictionary|
# |----|----|----|
# |`Format`|Text format|Python Object|
# |`Quotes`|Keys must be in double quotes ""| Keys can be in single or double quotes|
# |`Data Type`|Limited types| Supports many types|
# |`Used for`|Data Transfer/storage|Programming logic|

# %% [markdown]
# Python Dictionary

# %%
data = {'name':"Gayatri","age":65}
print(data)
print(type(data))
# Out:
# {'name': 'Gayatri', 'age': 65}
# <class 'dict'>

# %% [markdown]
# JSON String

# %% [markdown]
# `{"name":"Gayatri","age":65}`

# %% [markdown]
# ### 3. JSON Data Types
#
# JSON supports only these types:
# ---
# |JSON Type|Python Equivalent|
# |---|----|
# |string|str|
# |number|integer,float|
# |object| dict|
# |array|list|
# |boolean:true/false|bool:True/False|
# |null|None|
#
# ### Example JSON

# %% [markdown]
# ``` text
#     {
#     "name":"Nitesh",
#     "marks":[85,96,85],
#     "passed":true,
#     "address":null
#     }```

# %% [markdown]
# #### Python JSON Module
#
# Python provides a built-in module:
#
# Import it like this
#
# `import json`

# %%
import json

# %%
# help(json)

# %% [markdown]
# This Module used for:
#
# * Convert python object ➼ JSON
# * Convert JSON ➼ Python Object
# * Reading/Writing JSON file

# %% [markdown]
# ### 5. Convery Python Dictionary to JSON
#
# This is Called Serialization
#
# json.dumps() ➼ Converts python object to JSON String

# %%
import json

# %%
data = {
    "name":"Gayatri",
    'age':105,
    'city':"NOIDA"
}
print(data,type(data))
# Out:
# {'name': 'Gayatri', 'age': 105, 'city': 'NOIDA'} <class 'dict'>

# %%
json_data = json.dumps(data)
print(json_data)
print(type(json_data))

# not accessible
# Out:
# {"name": "Gayatri", "age": 105, "city": "NOIDA"}
# <class 'str'>

# %% [markdown]
# Note:
#
# So, dumps() return JSON string.

# %% [markdown]
# ### 6. Convert JSON to Python Dictionary
#
# This is called Deserialization
#
# json.loads() ➼ Convert JSON string to Python Object

# %%
json_string = '{"name": "Gayatri", "age": 105, "city": "NOIDA"}'
print(json_string,type(json_string))
# Out:
# {"name": "Gayatri", "age": 105, "city": "NOIDA"} <class 'str'>

# %%
python_data  = json.loads(json_string)
print(python_data,type(python_data))
# Out:
# {'name': 'Gayatri', 'age': 105, 'city': 'NOIDA'} <class 'dict'>

# %%
python_data['name'] = "Gayatri Gaware"
python_data
# Out:
# {'name': 'Gayatri Gaware', 'age': 105, 'city': 'NOIDA'}

# %% [markdown]
# #### 7. Wrting JSON Data to a File
#
# ----
#
# json.dump ➼ Write python object into JSON File

# %%
data = {
    "id":101,
    "name":"Gayatri Gaware",
    "skill":["Python","Django","JavaScript","Database"]
}
print(data,type(data))
# Out:
# {'id': 101, 'name': 'Gayatri Gaware', 'skill': ['Python', 'Django', 'JavaScript', 'Database']} <class 'dict'>

# %% [markdown]
# ##### create a file to store information

# %%
with open("student.json",'w') as file:
    json.dump(data,file)

# %% [markdown]
# ### 8. Reading JSON Data From a File
#
# json.load() ➼ Read JSON File into Python Object

# %%
with open("student.json","r") as f:
    data = json.load(f)
    print(data)
    print(type(data))
# Out:
# {'id': 101, 'name': 'Gayatri Gaware', 'skill': ['Python', 'Django', 'JavaScript', 'Database']}
# <class 'dict'>

# %% [markdown]
# ### 9. dumps() vs dump() and lodas() vs load()
#
# ----
# |Function|Used For| Input| Output|
# |----|----|----|----|
# |json.dumps()|Python ➼ JSON string| Python Object | JSON string|
# |json.dump()| Python ➼ JSON file|Pytyhon Object+File|Writes to file|
# |json.loads()|JSON string ➼ Python| JSON string| Python Object|
# |json.load()|JSON file ➼ Python|File|Python Object|

# %% [markdown]
# ### 10. Preety Print JSON [Indentation]
#
# By default JSON is one-line.

# %%
data  = {"name":"Geeta","age":105, "city":"Dwarka"}
print(data)

print(json.dumps(data, indent=4))
# Out:
# {'name': 'Geeta', 'age': 105, 'city': 'Dwarka'}
# {
#     "name": "Geeta",
#     "age": 105,
#     "city": "Dwarka"
# }

# %%
## 11. Sort JSON Keys

data = {"b":2,"a":1,"c":3}
print(data)

print(json.dumps(data,indent=4, sort_keys=False))
# Out:
# {'b': 2, 'a': 1, 'c': 3}
# {
#     "b": 2,
#     "a": 1,
#     "c": 3
# }

# %%
data = {"b":2,"a":1,"c":3}
print(data)

print(json.dumps(data,indent=4, sort_keys=True))
# Out:
# {'b': 2, 'a': 1, 'c': 3}
# {
#     "a": 1,
#     "b": 2,
#     "c": 3
# }

# %% [markdown]
# ## 12. JSON with List of Dictionary

# %%
import json

# %%
students = [
    {"id":1,"name":"Asha"},
    {"id":2,"name":"Nitesh"},
    {"id":3,"name":"Neha"}
]
print(students)
print(type(students))
# Out:
# [{'id': 1, 'name': 'Asha'}, {'id': 2, 'name': 'Nitesh'}, {'id': 3, 'name': 'Neha'}]
# <class 'list'>

# %%
print(json.dumps(students))
# Out:
# [{"id": 1, "name": "Asha"}, {"id": 2, "name": "Nitesh"}, {"id": 3, "name": "Neha"}]

# %%
print(json.dumps(students,indent=4))
# Out:
# [
#     {
#         "id": 1,
#         "name": "Asha"
#     },
#     {
#         "id": 2,
#         "name": "Nitesh"
#     },
#     {
#         "id": 3,
#         "name": "Neha"
#     }
# ]

# %% [markdown]
# ### 13. Working with Nested JSON
#
# Example nested JSON:

# %%
import json

# %%
data = {
    "employee":{
        "id":501,
        "name":"Nitesh",
        "department":{
            "dept_name":"IT",
            "location":"Bangaluru"
        }
    }
}
print(data)
# Out:
# {'employee': {'id': 501, 'name': 'Nitesh', 'department': {'dept_name': 'IT', 'location': 'Bangaluru'}}}

# %%
dataJson=json.dumps(data,indent=4)
print(dataJson)
# Out:
# {
#     "employee": {
#         "id": 501,
#         "name": "Nitesh",
#         "department": {
#             "dept_name": "IT",
#             "location": "Bangaluru"
#         }
#     }
# }

# %% [markdown]
# ### Access Nested Value

# %%
pythonObject = json.loads(dataJson)
print(pythonObject)
# Out:
# {'employee': {'id': 501, 'name': 'Nitesh', 'department': {'dept_name': 'IT', 'location': 'Bangaluru'}}}

# %%
data["employee"]['department']['location']
# Out:
# 'Bangaluru'

# %%
### 14. Convert Python object to JSON with Custom Formatting

data = {"name":"Anil","age":24}
print(json.dumps(data,separators=(",",":")))
# Out:
# {"name":"Anil","age":24}

# %%
print(json.dumps(data,separators=("/","-")))
# Out:
# {"name"-"Anil"/"age"-24}

# %%
### JSON Encoding Problem ()

from datetime import datetime

data = {"time":datetime.now()}
print(data)
# Out:
# {'time': datetime.datetime(2026, 7, 23, 18, 41, 21, 991613)}

# %%
print(json.dumps(data))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 print(json.dumps(data))
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\json\__init__.py:235, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     230 # cached encoder
#     231 if (not skipkeys and ensure_ascii and
#     232     check_circular and allow_nan and
#     233     cls is None and indent is None and separators is None and
#     234     default is None and not sort_keys and not kw):
# --> 235     return _default_encoder.encode(obj)
#     236 if cls is None:
#     237     cls = JSONEncoder
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\json\encoder.py:202, in JSONEncoder.encode(self, o)
#     198         return encode_basestring(o)
#     199 # This doesn't pass the iterator directly to ''.join() because the
# ...

# %%
from datetime import datetime

data = {"time":str(datetime.now())}
print(data)
# Out:
# {'time': '2026-07-23 18:42:31.960197'}

# %%
print(json.dumps(data))
# Out:
# {"time": "2026-07-23 18:42:31.960197"}

# %% [markdown]
# ### Important Interview Question
#
# #### Q1. What is JSON?
# `A light weight fromat for storing and transferring data.`
# #### Q2. What is deserialization?
# `Converting JSON string into Python objects.`
# #### Q3. What id Serialization?
# `Converting Python Object into JSON String.`
# #### Q4. Difference between dump and dumps?
# `dump writes to file`
# `dumps convert to string`
# #### Q5. What is difference between load and loads?
# `load reads from file.`
# `loads reads from string`
#
# -----
#
#
# #### KeyPoints
#
# * ✔️JSON is always string-based.
# * ✔️JSON keys must be double quotes.
# * ✔️JSON does not support Python tuple/set directly.
# * ✔️Use indent=4 for readablility.
# * ✔️Use json.load() for file reading.
# * ✔️ Use json.loads() for string reading.
